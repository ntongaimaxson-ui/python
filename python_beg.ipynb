# %%
#tuple

tuple_scoops = (1,2,3,2,1)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops[0]
# Out:
# 1

# %%
#sets

daily_pints = {1,2,3}

# %%
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3}

# %%
my_daily_prints = {1,2,5,4,7,67,3,2,45}

# %%
print(my_daily_prints)
# Out:
# {1, 2, 67, 4, 5, 3, 7, 45}

# %%
wifes_daily_prints = {3,5,2,5,7,43,2,5}

# %%
print(wifes_daily_prints)
# Out:
# {2, 3, 5, 7, 43}

# %% [raw]
# print(my_daily_prints & wifes_daily_prints)

# %%
#dictionaries

# %%
#operators

10 == 21
# Out:
# False

# %%
#if_elif_else statement
# Out:
#   Cell In[3], line 4
#     print(it worked!)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
if 25 > 10:
    print('it worked!')
# Out:
# it worked!

# %%
if 25 < 10:
    print('it worked!')
else:
    print('it did not work')
# Out:
# it did not work

# %%
if 25 < 10:
    print('it worked!')
elif 25<30:
    print('elif worked')
else:
    print('it did not work')
# Out:
# elif worked

# %%
if (25 < 10) or (3>1):
    print('it worked!')
elif 25<30:
    print('elif worked')
else:
    print('it did not work')
# Out:
# it worked!

# %%
if (25 < 10) and (3>1):
    print('it worked!')
elif 25<30:
    print('elif worked')
else:
    print('it did not work')
# Out:
# elif worked

# %%
# for loops

# %%
type('me')
# Out:
# str

# %%
integers = [1,2,3,4,5]

# %%
for number in integers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
integers = [1,2,3,4,5]

# %%
for number in integers:
    print('yap man!')
# Out:
# yap man!
# yap man!
# yap man!
# yap man!
# yap man!

# %%
#DICTIONARIES

# %%
ice_cream_dict = {'name': 'maxson','favorite': 'vanilla flavor', 'numbers in a day':5}

# %%
print(ice_cream_dict)
# Out:
# {'name': 'maxson', 'favorite': 'vanilla flavor', 'numbers in a day': 5}

# %%
ice_cream_dict = {'name': 'maxson','favorite': 'vanilla flavor', 'numbers in a day':5}

# %%
ice_cream_dict = {'name': 'maxson','favorite': 'vanilla flavor', 'numbers in a day':5}

# %%
for cream in ice_cream_dict.values():
    print(cream)
# Out:
# maxson
# vanilla flavor
# 5

# %%
for key, value in ice_cream_dict.items():
    print(key, '-', value)
# Out:
# name - maxson
# favorite - vanilla flavor
# numbers in a day - 5

# %%
flavors =['orange', 'blackcurrent', 'passion']
topping =['bread', 'mandazi', 'ugali']

# %%
for one in flavors:
    for two in topping:
        print(one, 'topped with', two)
# Out:
# orange topped with bread
# orange topped with mandazi
# orange topped with ugali
# blackcurrent topped with bread
# blackcurrent topped with mandazi
# blackcurrent topped with ugali
# passion topped with bread
# passion topped with mandazi
# passion topped with ugali
